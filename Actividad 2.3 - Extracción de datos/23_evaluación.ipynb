# %% [markdown]
# # Primera evaluación

# %%
import pandas as pd

# %%
# Cargamos la base de datos
df = pd.read_csv('listings - New York.csv')
df
# Out:
#                         id                                       listing_url  \
# 0                     2595                 https://www.airbnb.com/rooms/2595
# 1                     6848                 https://www.airbnb.com/rooms/6848
# 2                     6872                 https://www.airbnb.com/rooms/6872
# 3                     6990                 https://www.airbnb.com/rooms/6990
# 4                     7064                 https://www.airbnb.com/rooms/7064
# ...                    ...                                               ...
# 37543  1281096465598617765  https://www.airbnb.com/rooms/1281096465598617765
# 37544  1281230979116575465  https://www.airbnb.com/rooms/1281230979116575465
# 37545  1281263542832791722  https://www.airbnb.com/rooms/1281263542832791722
# 37546  1281431427554747842  https://www.airbnb.com/rooms/1281431427554747842
# 37547  1281465359952960262  https://www.airbnb.com/rooms/1281465359952960262
#
# ...

# %%
# a) Primer filtro: 5 registros de host_name diferentes
# Aquí se seleccionan los registros que contienen los nombres de los hosts Anna, Obed, Michael, Edward y Jennifer
filtro1 = df[df['host_name'].isin(['Anna', 'Obed', 'Michael', 'Edward', 'Jennifer'])]
filtro1.to_csv('filtro1.csv')
filtro1
# Out:
#                         id                                       listing_url  \
# 0                     2595                 https://www.airbnb.com/rooms/2595
# 11                   12192                https://www.airbnb.com/rooms/12192
# 21                   17037                https://www.airbnb.com/rooms/17037
# 46                   34760                https://www.airbnb.com/rooms/34760
# 47                   36121                https://www.airbnb.com/rooms/36121
# ...                    ...                                               ...
# 37393  1272803789903111695  https://www.airbnb.com/rooms/1272803789903111695
# 37438  1274820999428562667  https://www.airbnb.com/rooms/1274820999428562667
# 37467  1277423170263506742  https://www.airbnb.com/rooms/1277423170263506742
# 37478  1278216388903243988  https://www.airbnb.com/rooms/1278216388903243988
# 37509  1279032594757762626  https://www.airbnb.com/rooms/1279032594757762626
#
# ...

# %%
# b) Segundo filtro: los registros de los host que se hayan unido a Airbnb antes de 2019
# Para este filtro, usaremos la columna 'host_since' que contiene la fecha en la que el host se unió a Airbnb
filtro2 = df[df['host_since'] < '2019-01-01']
filtro2.to_csv('filtro2.csv')
filtro2
# Out:
#                         id                                       listing_url  \
# 0                     2595                 https://www.airbnb.com/rooms/2595
# 1                     6848                 https://www.airbnb.com/rooms/6848
# 2                     6872                 https://www.airbnb.com/rooms/6872
# 3                     6990                 https://www.airbnb.com/rooms/6990
# 4                     7064                 https://www.airbnb.com/rooms/7064
# ...                    ...                                               ...
# 37540  1280611088367758993  https://www.airbnb.com/rooms/1280611088367758993
# 37542  1280784833142464571  https://www.airbnb.com/rooms/1280784833142464571
# 37543  1281096465598617765  https://www.airbnb.com/rooms/1281096465598617765
# 37544  1281230979116575465  https://www.airbnb.com/rooms/1281230979116575465
# 37545  1281263542832791722  https://www.airbnb.com/rooms/1281263542832791722
#
# ...

# %%
# c) Tercer filtro: los registros de los host que que responden a más tardar un día
# Para este filtro, usaremos la columna 'host_response_time' que contiene el tiempo de respuesta del host
filtro3 = df[df['host_response_time'] == 'within a day']
filtro3.to_csv('filtro3.csv')
filtro3
# Out:
#                         id                                       listing_url  \
# 0                     2595                 https://www.airbnb.com/rooms/2595
# 25                   19174                https://www.airbnb.com/rooms/19174
# 26                   19282                https://www.airbnb.com/rooms/19282
# 31                   23135                https://www.airbnb.com/rooms/23135
# 45                   33009                https://www.airbnb.com/rooms/33009
# ...                    ...                                               ...
# 37488  1278405210416683692  https://www.airbnb.com/rooms/1278405210416683692
# 37496  1278933099954171674  https://www.airbnb.com/rooms/1278933099954171674
# 37512  1279173173417584963  https://www.airbnb.com/rooms/1279173173417584963
# 37525  1279652376594658493  https://www.airbnb.com/rooms/1279652376594658493
# 37539  1280557443877722005  https://www.airbnb.com/rooms/1280557443877722005
#
# ...

# %%
# d) Cuarto filtro: los registros que tengan al menos 5 accommodates
# Para este filtro, usaremos la columna 'accommodates' que contiene el número de personas que pueden ser acomodadas
filtro4 = df[df['accommodates'] >= 5]
filtro4.to_csv('filtro4.csv')
filtro4
# Out:
#                         id                                       listing_url  \
# 7                     8490                 https://www.airbnb.com/rooms/8490
# 20                   16974                https://www.airbnb.com/rooms/16974
# 33                   24285                https://www.airbnb.com/rooms/24285
# 55                   42300                https://www.airbnb.com/rooms/42300
# 62                   45910                https://www.airbnb.com/rooms/45910
# ...                    ...                                               ...
# 37511  1279142567874404675  https://www.airbnb.com/rooms/1279142567874404675
# 37515  1279294929824671110  https://www.airbnb.com/rooms/1279294929824671110
# 37526  1279685955269847249  https://www.airbnb.com/rooms/1279685955269847249
# 37538  1280496094601575642  https://www.airbnb.com/rooms/1280496094601575642
# 37544  1281230979116575465  https://www.airbnb.com/rooms/1281230979116575465
#
# ...

# %%
# e) Quinto filtro: los registros de los tipos de cuarto 'Entire home/apt' y 'Private room'
# Para este filtro, usaremos la columna 'room_type' que contiene el tipo de cuarto
filtro5 = df[df['room_type'].isin(['Entire home/apt', 'Private room'])]
filtro5.to_csv('filtro5.csv')
filtro5
# Out:
#                         id                                       listing_url  \
# 0                     2595                 https://www.airbnb.com/rooms/2595
# 1                     6848                 https://www.airbnb.com/rooms/6848
# 2                     6872                 https://www.airbnb.com/rooms/6872
# 3                     6990                 https://www.airbnb.com/rooms/6990
# 4                     7064                 https://www.airbnb.com/rooms/7064
# ...                    ...                                               ...
# 37543  1281096465598617765  https://www.airbnb.com/rooms/1281096465598617765
# 37544  1281230979116575465  https://www.airbnb.com/rooms/1281230979116575465
# 37545  1281263542832791722  https://www.airbnb.com/rooms/1281263542832791722
# 37546  1281431427554747842  https://www.airbnb.com/rooms/1281431427554747842
# 37547  1281465359952960262  https://www.airbnb.com/rooms/1281465359952960262
#
# ...

# %%
# f) Sexto filtro: los registros que a lo mucho cuenten con 4 camas
# Para este filtro, usaremos la columna 'beds' que contiene el número de camas
filtro6 = df[df['beds'] <= 4]   
filtro6.to_csv('filtro6.csv')
filtro6
# Out:
#                         id                                       listing_url  \
# 0                     2595                 https://www.airbnb.com/rooms/2595
# 1                     6848                 https://www.airbnb.com/rooms/6848
# 2                     6872                 https://www.airbnb.com/rooms/6872
# 3                     6990                 https://www.airbnb.com/rooms/6990
# 5                     7097                 https://www.airbnb.com/rooms/7097
# ...                    ...                                               ...
# 37543  1281096465598617765  https://www.airbnb.com/rooms/1281096465598617765
# 37544  1281230979116575465  https://www.airbnb.com/rooms/1281230979116575465
# 37545  1281263542832791722  https://www.airbnb.com/rooms/1281263542832791722
# 37546  1281431427554747842  https://www.airbnb.com/rooms/1281431427554747842
# 37547  1281465359952960262  https://www.airbnb.com/rooms/1281465359952960262
#
# ...

# %%
# g) Séptimo filtro: los registros que tengan 1 baño o sean superhosts pero con la condición de que todos sean instant bookable
# Para este filtro, usaremos las columnas 'bathrooms', 'host_is_superhost' y 'instant_bookable'
filtro7 = df[((df['bathrooms'] == 1) | (df['host_is_superhost'] == 't')) & (df['instant_bookable'] == 't')]
filtro7.to_csv('filtro7.csv')
filtro7
# Out:
#                         id                                       listing_url  \
# 5                     7097                 https://www.airbnb.com/rooms/7097
# 23                   18728                https://www.airbnb.com/rooms/18728
# 35                   26785                https://www.airbnb.com/rooms/26785
# 39                   29628                https://www.airbnb.com/rooms/29628
# 43                   31994                https://www.airbnb.com/rooms/31994
# ...                    ...                                               ...
# 37531  1279759802665836048  https://www.airbnb.com/rooms/1279759802665836048
# 37532  1280015420663996112  https://www.airbnb.com/rooms/1280015420663996112
# 37537  1280441002841407586  https://www.airbnb.com/rooms/1280441002841407586
# 37541  1280779984673933587  https://www.airbnb.com/rooms/1280779984673933587
# 37545  1281263542832791722  https://www.airbnb.com/rooms/1281263542832791722
#
# ...

# %%
# h) Octavo filtro: los registros cuyo review score cleanliness sea menor a 3 y review score rating sea mayor a 3
# Para este filtro, usaremos las columnas 'review_scores_cleanliness' y 'review_scores_rating'
filtro8 = df[(df['review_scores_cleanliness'] < 3) & (df['review_scores_rating'] > 3)]
filtro8.to_csv('filtro8.csv')
filtro8
# Out:
#                         id                                       listing_url  \
# 284                 258930               https://www.airbnb.com/rooms/258930
# 305                 271694               https://www.airbnb.com/rooms/271694
# 1325               2128464              https://www.airbnb.com/rooms/2128464
# 1378               2238300              https://www.airbnb.com/rooms/2238300
# 1789               3362302              https://www.airbnb.com/rooms/3362302
# ...                    ...                                               ...
# 32296  1047134824286187568  https://www.airbnb.com/rooms/1047134824286187568
# 33534  1103681070563059981  https://www.airbnb.com/rooms/1103681070563059981
# 34352  1136151512842150679  https://www.airbnb.com/rooms/1136151512842150679
# 35445  1176936179607448594  https://www.airbnb.com/rooms/1176936179607448594
# 36372  1219016339909757511  https://www.airbnb.com/rooms/1219016339909757511
#
# ...
